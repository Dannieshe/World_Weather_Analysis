# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the timelibrary and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | langxiang
# Processing Record 3 of Set 1 | ajaccio
# Processing Record 4 of Set 1 | jacareacanga
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | san patricio
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | ixtapa
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | vardo
# Processing Record 13 of Set 1 | serebryanyy bor
# Processing Record 14 of Set 1 | carutapera
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | kieta
# Processing Record 17 of Set 1 | orbetello
# Processing Record 18 of Set 1 | dali
# Processing Record 19 of Set 1 | banjar
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | quelimane
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | tautira
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | aneho
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | constitucion
# Processing Record 31 of Set 1 | tahe
# Processing Record 32 of Set 1 | rosetta
# Processing Record 33 of Set 1 | kabare
# Processing Record 34 of Set 1 | port jervis
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | itupiranga
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | veraval
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | lagos
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | aberdeen
# Processing Record 44 of Set 1 | raudeberg
# Processing Record 45 of Set 1 | cabo san lucas
# Processing Record 46 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | trairi
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | sept-iles
# Processing Record 3 of Set 2 | guerrero negro
# Processing Record 4 of Set 2 | prince rupert
# Processing Record 5 of Set 2 | fort nelson
# Processing Record 6 of Set 2 | pangnirtung
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | clyde river
# Processing Record 9 of Set 2 | bulgan
# Processing Record 10 of Set 2 | richards bay
# Processing Record 11 of Set 2 | bathsheba
# Processing Record 12 of Set 2 | provideniya
# Processing Record 13 of Set 2 | gisborne
# Processing Record 14 of Set 2 | oussouye
# Processing Record 15 of Set 2 | bozhou
# Processing Record 16 of Set 2 | san juan del sur
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | evensk
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | namatanai
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | nouakchott
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | tutoia
# Processing Record 27 of Set 2 | ambalema
# Processing Record 28 of Set 2 | dudinka
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | blagoyevo
# Processing Record 31 of Set 2 | castanhal
# Processing Record 32 of Set 2 | jijiga
# Processing Record 33 of Set 2 | alexandria
# Processing Record 34 of Set 2 | kuvandyk
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | bambous virieux
# Processing Record 39 of Set 2 | hambantota
# Processing Record 40 of Set 2 | santa cruz de la palma
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | nelson bay
# Processing Record 44 of Set 2 | lima
# Processing Record 45 of Set 2 | luanshya
# Processing Record 46 of Set 2 | knysna
# Processing Record 47 of Set 2 | zeya
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | codrington
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | hamilton
# Processing Record 2 of Set 3 | waipawa
# Processing Record 3 of Set 3 | vila velha
# Processing Record 4 of Set 3 | saran
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | vanimo
# Processing Record 7 of Set 3 | alexandroupoli
# Processing Record 8 of Set 3 | coquimbo
# Processing Record 9 of Set 3 | nivala
# Processing Record 10 of Set 3 | san vicente
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | vestmannaeyjar
# Processing Record 13 of Set 3 | marsh harbour
# Processing Record 14 of Set 3 | gazanjyk
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | tucuma
# Processing Record 17 of Set 3 | sandnessjoen
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | xiaoweizhai
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | talcahuano
# Processing Record 23 of Set 3 | dhidhdhoo
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | port blair
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | roald
# Processing Record 30 of Set 3 | yakeshi
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 3 | mehamn
# Processing Record 35 of Set 3 | port hardy
# Processing Record 36 of Set 3 | saint-pierre
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | kaitangata
# Processing Record 39 of Set 3 | necochea
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | zhigansk
# Processing Record 42 of Set 3 | los llanos de aridane
# Processing Record 43 of Set 3 | antalaha
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | portland
# Processing Record 46 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 3 | aksum
# Processing Record 48 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 3 | fomboni
# Processing Record 50 of Set 3 | ostrovnoy
# Processing Record 1 of Set 4 | cherskiy
# Processing Record 2 of Set 4 | abu dhabi
# Processing Record 3 of Set 4 | marienburg
# Processing Record 4 of Set 4 | zhangjiakou
# Processing Record 5 of Set 4 | cervo
# Processing Record 6 of Set 4 | bowling green
# Processing Record 7 of Set 4 | amahai
# Processing Record 8 of Set 4 | fuxin
# Processing Record 9 of Set 4 | moron
# Processing Record 10 of Set 4 | grand gaube
# Processing Record 11 of Set 4 | deputatskiy
# Processing Record 12 of Set 4 | santa maria
# Processing Record 13 of Set 4 | liverpool
# Processing Record 14 of Set 4 | fernley
# Processing Record 15 of Set 4 | ilhabela
# Processing Record 16 of Set 4 | prado
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | kathmandu
# Processing Record 19 of Set 4 | carora
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | mount pleasant
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | mahajanga
# Processing Record 24 of Set 4 | lorengau
# Processing Record 25 of Set 4 | olafsvik
# Processing Record 26 of Set 4 | cap malheureux
# Processing Record 27 of Set 4 | gamba
# Processing Record 28 of Set 4 | liniere
# City not found. Skipping...
# Processing Record 29 of Set 4 | krasnoselkup
# Processing Record 30 of Set 4 | domoni
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | hervey bay
# Processing Record 33 of Set 4 | maues
# Processing Record 34 of Set 4 | porto novo
# Processing Record 35 of Set 4 | kitakata
# Processing Record 36 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 4 | faanui
# Processing Record 38 of Set 4 | buraydah
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | seoul
# Processing Record 41 of Set 4 | mayo
# Processing Record 42 of Set 4 | antofagasta
# Processing Record 43 of Set 4 | san cristobal
# Processing Record 44 of Set 4 | bolkhov
# Processing Record 45 of Set 4 | soddy-daisy
# Processing Record 46 of Set 4 | namibe
# Processing Record 47 of Set 4 | mortka
# Processing Record 48 of Set 4 | ribeira grande
# Processing Record 49 of Set 4 | kodiak
# Processing Record 50 of Set 4 | axim
# Processing Record 1 of Set 5 | tasiilaq
# Processing Record 2 of Set 5 | bathurst
# Processing Record 3 of Set 5 | artyom
# Processing Record 4 of Set 5 | saint-pascal
# City not found. Skipping...
# Processing Record 5 of Set 5 | rocha
# Processing Record 6 of Set 5 | hailar
# Processing Record 7 of Set 5 | saint george
# Processing Record 8 of Set 5 | ak-dovurak
# Processing Record 9 of Set 5 | chernyshevskiy
# Processing Record 10 of Set 5 | harrisonville
# Processing Record 11 of Set 5 | dekar
# Processing Record 12 of Set 5 | birin
# Processing Record 13 of Set 5 | waingapu
# Processing Record 14 of Set 5 | vilhena
# Processing Record 15 of Set 5 | tomatlan
# Processing Record 16 of Set 5 | georgetown
# Processing Record 17 of Set 5 | sinazongwe
# Processing Record 18 of Set 5 | ambovombe
# Processing Record 19 of Set 5 | ahuimanu
# Processing Record 20 of Set 5 | lata
# Processing Record 21 of Set 5 | minden
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | cabedelo
# Processing Record 24 of Set 5 | powassan
# Processing Record 25 of Set 5 | nome
# Processing Record 26 of Set 5 | mago
# Processing Record 27 of Set 5 | paamiut
# Processing Record 28 of Set 5 | mosquera
# Processing Record 29 of Set 5 | tiarei
# Processing Record 30 of Set 5 | concordia
# Processing Record 31 of Set 5 | torbay
# Processing Record 32 of Set 5 | ponta do sol
# Processing Record 33 of Set 5 | gualeguay
# Processing Record 34 of Set 5 | galle
# Processing Record 35 of Set 5 | kamsack
# Processing Record 36 of Set 5 | aketi
# Processing Record 37 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 5 | sitka
# Processing Record 39 of Set 5 | khasan
# Processing Record 40 of Set 5 | pital
# Processing Record 41 of Set 5 | opuwo
# Processing Record 42 of Set 5 | hovd
# Processing Record 43 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 5 | college
# Processing Record 46 of Set 5 | sawakin
# Processing Record 47 of Set 5 | souillac
# Processing Record 48 of Set 5 | haines junction
# Processing Record 49 of Set 5 | saldanha
# Processing Record 50 of Set 5 | griffith
# Processing Record 1 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 6 | kamloops
# Processing Record 3 of Set 6 | gardner
# Processing Record 4 of Set 6 | jacqueville
# Processing Record 5 of Set 6 | comodoro rivadavia
# Processing Record 6 of Set 6 | rodino
# Processing Record 7 of Set 6 | qasigiannguit
# Processing Record 8 of Set 6 | odienne
# Processing Record 9 of Set 6 | kjollefjord
# Processing Record 10 of Set 6 | kenitra
# Processing Record 11 of Set 6 | baoro
# Processing Record 12 of Set 6 | salalah
# Processing Record 13 of Set 6 | the valley
# Processing Record 14 of Set 6 | ermoupolis
# Processing Record 15 of Set 6 | faro
# Processing Record 16 of Set 6 | boa vista
# Processing Record 17 of Set 6 | lebedyan
# Processing Record 18 of Set 6 | sao joao da barra
# Processing Record 19 of Set 6 | ust-karsk
# Processing Record 20 of Set 6 | macomb
# Processing Record 21 of Set 6 | sindor
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | prachuap khiri khan
# Processing Record 24 of Set 6 | villa rica
# Processing Record 25 of Set 6 | kenai
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | gizo
# Processing Record 28 of Set 6 | florence
# Processing Record 29 of Set 6 | nago
# Processing Record 30 of Set 6 | pacifica
# Processing Record 31 of Set 6 | pisco
# Processing Record 32 of Set 6 | santa rosa
# Processing Record 33 of Set 6 | srednekolymsk
# Processing Record 34 of Set 6 | mar del plata
# Processing Record 35 of Set 6 | najran
# Processing Record 36 of Set 6 | tecoanapa
# Processing Record 37 of Set 6 | udomlya
# Processing Record 38 of Set 6 | andilamena
# Processing Record 39 of Set 6 | sakakah
# Processing Record 40 of Set 6 | hofn
# Processing Record 41 of Set 6 | aykhal
# Processing Record 42 of Set 6 | puqi
# Processing Record 43 of Set 6 | stabat
# Processing Record 44 of Set 6 | wanning
# Processing Record 45 of Set 6 | tuatapere
# Processing Record 46 of Set 6 | fortuna
# Processing Record 47 of Set 6 | bastos
# Processing Record 48 of Set 6 | gigmoto
# Processing Record 49 of Set 6 | mega
# Processing Record 50 of Set 6 | abaza
# Processing Record 1 of Set 7 | visby
# Processing Record 2 of Set 7 | mogocha
# Processing Record 3 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 7 | rio grande
# Processing Record 5 of Set 7 | caluquembe
# Processing Record 6 of Set 7 | khvastovichi
# Processing Record 7 of Set 7 | port elizabeth
# Processing Record 8 of Set 7 | kloulklubed
# Processing Record 9 of Set 7 | kargopol
# Processing Record 10 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 7 | riberalta
# Processing Record 12 of Set 7 | inhambane
# Processing Record 13 of Set 7 | makakilo city
# Processing Record 14 of Set 7 | aklavik
# Processing Record 15 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 7 | igarka
# Processing Record 17 of Set 7 | merauke
# Processing Record 18 of Set 7 | taiyuan
# Processing Record 19 of Set 7 | marrakesh
# Processing Record 20 of Set 7 | soyo
# Processing Record 21 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 7 | ginir
# Processing Record 23 of Set 7 | altay
# Processing Record 24 of Set 7 | rafai
# Processing Record 25 of Set 7 | amapa
# Processing Record 26 of Set 7 | kaina
# Processing Record 27 of Set 7 | kuytun
# Processing Record 28 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 7 | chokurdakh
# Processing Record 30 of Set 7 | mount isa
# Processing Record 31 of Set 7 | dahuk
# Processing Record 32 of Set 7 | emerald
# Processing Record 33 of Set 7 | port moresby
# Processing Record 34 of Set 7 | boyolangu
# Processing Record 35 of Set 7 | kaeo
# Processing Record 36 of Set 7 | narsaq
# Processing Record 37 of Set 7 | maceio
# Processing Record 38 of Set 7 | tahlequah
# Processing Record 39 of Set 7 | victoria
# Processing Record 40 of Set 7 | buala
# Processing Record 41 of Set 7 | acapulco
# Processing Record 42 of Set 7 | olsztyn
# Processing Record 43 of Set 7 | dingle
# Processing Record 44 of Set 7 | upernavik
# Processing Record 45 of Set 7 | bocas del toro
# Processing Record 46 of Set 7 | santa isabel do rio negro
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | la ronge
# Processing Record 49 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 7 | tazovskiy
# Processing Record 1 of Set 8 | belmonte
# Processing Record 2 of Set 8 | yar-sale
# Processing Record 3 of Set 8 | ercis
# Processing Record 4 of Set 8 | tatsinskaya
# City not found. Skipping...
# Processing Record 5 of Set 8 | redmond
# Processing Record 6 of Set 8 | bowen
# Processing Record 7 of Set 8 | omsukchan
# Processing Record 8 of Set 8 | bridlington
# Processing Record 9 of Set 8 | ponta delgada
# Processing Record 10 of Set 8 | erenhot
# Processing Record 11 of Set 8 | idil
# Processing Record 12 of Set 8 | puerto escondido
# Processing Record 13 of Set 8 | okhotsk
# Processing Record 14 of Set 8 | fenoarivo
# Processing Record 15 of Set 8 | nyuksenitsa
# Processing Record 16 of Set 8 | sangar
# Processing Record 17 of Set 8 | roma
# Processing Record 18 of Set 8 | lerwick
# Processing Record 19 of Set 8 | luderitz
# Processing Record 20 of Set 8 | khilok
# Processing Record 21 of Set 8 | berlevag
# Processing Record 22 of Set 8 | isangel
# Processing Record 23 of Set 8 | nenagh
# Processing Record 24 of Set 8 | sibolga
# Processing Record 25 of Set 8 | chulman
# Processing Record 26 of Set 8 | bunia
# Processing Record 27 of Set 8 | kushmurun
# Processing Record 28 of Set 8 | broken hill
# Processing Record 29 of Set 8 | shorewood
# Processing Record 30 of Set 8 | rio gallegos
# Processing Record 31 of Set 8 | kedrovyy
# Processing Record 32 of Set 8 | broome
# Processing Record 33 of Set 8 | sokoni
# Processing Record 34 of Set 8 | davila
# Processing Record 35 of Set 8 | ekibastuz
# Processing Record 36 of Set 8 | la paz
# Processing Record 37 of Set 8 | lompoc
# Processing Record 38 of Set 8 | tepexi
# City not found. Skipping...
# Processing Record 39 of Set 8 | crotone
# Processing Record 40 of Set 8 | chuy
# Processing Record 41 of Set 8 | belaya gora
# Processing Record 42 of Set 8 | bogorodskoye
# Processing Record 43 of Set 8 | abu samrah
# Processing Record 44 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 8 | koungou
# Processing Record 46 of Set 8 | atbasar
# Processing Record 47 of Set 8 | vaniyambadi
# Processing Record 48 of Set 8 | porto santo
# Processing Record 49 of Set 8 | staryy nadym
# Processing Record 50 of Set 8 | tingo maria
# Processing Record 1 of Set 9 | sola
# Processing Record 2 of Set 9 | adrar
# Processing Record 3 of Set 9 | severomuysk
# Processing Record 4 of Set 9 | wahiawa
# Processing Record 5 of Set 9 | puerto carreno
# Processing Record 6 of Set 9 | avera
# Processing Record 7 of Set 9 | dalvik
# Processing Record 8 of Set 9 | luanda
# Processing Record 9 of Set 9 | develi
# Processing Record 10 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 11 of Set 9 | leeton
# Processing Record 12 of Set 9 | kemijarvi
# Processing Record 13 of Set 9 | victor harbor
# Processing Record 14 of Set 9 | daru
# Processing Record 15 of Set 9 | saint stephen
# Processing Record 16 of Set 9 | padang
# Processing Record 17 of Set 9 | touros
# Processing Record 18 of Set 9 | cayenne
# Processing Record 19 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 9 | caravelas
# Processing Record 21 of Set 9 | abastumani
# Processing Record 22 of Set 9 | shenjiamen
# Processing Record 23 of Set 9 | luganville
# Processing Record 24 of Set 9 | nikolskoye
# Processing Record 25 of Set 9 | korla
# Processing Record 26 of Set 9 | muravlenko
# Processing Record 27 of Set 9 | danielskuil
# Processing Record 28 of Set 9 | eston
# Processing Record 29 of Set 9 | mitu
# Processing Record 30 of Set 9 | santa marta
# Processing Record 31 of Set 9 | hammond
# Processing Record 32 of Set 9 | maningrida
# Processing Record 33 of Set 9 | krasnoznamensk
# Processing Record 34 of Set 9 | fort smith
# Processing Record 35 of Set 9 | ciudad bolivar
# Processing Record 36 of Set 9 | tipp city
# Processing Record 37 of Set 9 | severnyy
# Processing Record 38 of Set 9 | ballina
# Processing Record 39 of Set 9 | inongo
# Processing Record 40 of Set 9 | salamiyah
# Processing Record 41 of Set 9 | felanitx
# Processing Record 42 of Set 9 | leh
# Processing Record 43 of Set 9 | aguimes
# Processing Record 44 of Set 9 | sulangan
# Processing Record 45 of Set 9 | palmer
# Processing Record 46 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 9 | nyurba
# Processing Record 48 of Set 9 | mapiri
# Processing Record 49 of Set 9 | sioux lookout
# Processing Record 50 of Set 9 | ahipara
# Processing Record 1 of Set 10 | ati
# Processing Record 2 of Set 10 | arawa
# Processing Record 3 of Set 10 | northam
# Processing Record 4 of Set 10 | reconquista
# Processing Record 5 of Set 10 | teya
# Processing Record 6 of Set 10 | pascagoula
# Processing Record 7 of Set 10 | hami
# Processing Record 8 of Set 10 | sistranda
# Processing Record 9 of Set 10 | harper
# Processing Record 10 of Set 10 | bosaso
# Processing Record 11 of Set 10 | athabasca
# Processing Record 12 of Set 10 | maumere
# Processing Record 13 of Set 10 | mogadishu
# Processing Record 14 of Set 10 | husavik
# Processing Record 15 of Set 10 | komsomolskiy
# Processing Record 16 of Set 10 | toamasina
# Processing Record 17 of Set 10 | queenstown
# Processing Record 18 of Set 10 | turayf
# Processing Record 19 of Set 10 | abaete
# Processing Record 20 of Set 10 | yenagoa
# Processing Record 21 of Set 10 | vangaindrano
# Processing Record 22 of Set 10 | klupci
# Processing Record 23 of Set 10 | pithapuram
# Processing Record 24 of Set 10 | yulara
# Processing Record 25 of Set 10 | tura
# Processing Record 26 of Set 10 | pitimbu
# Processing Record 27 of Set 10 | kahului
# Processing Record 28 of Set 10 | auki
# Processing Record 29 of Set 10 | dedza
# Processing Record 30 of Set 10 | pechenga
# Processing Record 31 of Set 10 | ancud
# Processing Record 32 of Set 10 | zhicheng
# Processing Record 33 of Set 10 | hirara
# Processing Record 34 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 10 | khorramabad
# Processing Record 36 of Set 10 | zaraysk
# Processing Record 37 of Set 10 | port keats
# Processing Record 38 of Set 10 | basco
# Processing Record 39 of Set 10 | puro
# Processing Record 40 of Set 10 | ust-maya
# Processing Record 41 of Set 10 | kuandian
# Processing Record 42 of Set 10 | asau
# Processing Record 43 of Set 10 | zemio
# Processing Record 44 of Set 10 | vao
# Processing Record 45 of Set 10 | bandarbeyla
# Processing Record 46 of Set 10 | maple creek
# Processing Record 47 of Set 10 | dombarovskiy
# Processing Record 48 of Set 10 | nishihara
# Processing Record 49 of Set 10 | xique-xique
# Processing Record 50 of Set 10 | meulaboh
# Processing Record 1 of Set 11 | theologos
# City not found. Skipping...
# Processing Record 2 of Set 11 | kavaratti
# Processing Record 3 of Set 11 | acari
# Processing Record 4 of Set 11 | longyearbyen
# Processing Record 5 of Set 11 | kpandae
# Processing Record 6 of Set 11 | qianan
# Processing Record 7 of Set 11 | khash
# Processing Record 8 of Set 11 | sug-aksy
# City not found. Skipping...
# Processing Record 9 of Set 11 | ornskoldsvik
# Processing Record 10 of Set 11 | esperance
# Processing Record 11 of Set 11 | madimba
# Processing Record 12 of Set 11 | upata
# Processing Record 13 of Set 11 | mount gambier
# Processing Record 14 of Set 11 | kalmunai
# Processing Record 15 of Set 11 | verkhnevilyuysk
# Processing Record 16 of Set 11 | vila franca do campo
# Processing Record 17 of Set 11 | kota bahru
# Processing Record 18 of Set 11 | san policarpo
# Processing Record 19 of Set 11 | sabha
# Processing Record 20 of Set 11 | norcasia
# Processing Record 21 of Set 11 | pochutla
# Processing Record 22 of Set 11 | bodden town
# Processing Record 23 of Set 11 | elesbao veloso
# Processing Record 24 of Set 11 | tekkali
# Processing Record 25 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 26 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 11 | fergus falls
# Processing Record 28 of Set 11 | edson
# Processing Record 29 of Set 11 | dawei
# Processing Record 30 of Set 11 | alofi
# Processing Record 31 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 32 of Set 11 | zlobin
# Processing Record 33 of Set 11 | geraldton
# Processing Record 34 of Set 11 | chhatak
# Processing Record 35 of Set 11 | yen bai
# Processing Record 36 of Set 11 | kitsuki
# Processing Record 37 of Set 11 | miri
# Processing Record 38 of Set 11 | lagoa
# Processing Record 39 of Set 11 | shelburne
# Processing Record 40 of Set 11 | likasi
# Processing Record 41 of Set 11 | hisar
# Processing Record 42 of Set 11 | narasannapeta
# Processing Record 43 of Set 11 | manavgat
# Processing Record 44 of Set 11 | soavinandriana
# Processing Record 45 of Set 11 | sussex
# Processing Record 46 of Set 11 | jurm
# Processing Record 47 of Set 11 | chara
# Processing Record 48 of Set 11 | menongue
# Processing Record 49 of Set 11 | tavda
# Processing Record 50 of Set 11 | great bend
# Processing Record 1 of Set 12 | leningradskiy
# Processing Record 2 of Set 12 | ulladulla
# Processing Record 3 of Set 12 | weligama
# Processing Record 4 of Set 12 | saurimo
# Processing Record 5 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 12 | burnie
# Processing Record 7 of Set 12 | gravdal
# Processing Record 8 of Set 12 | nouadhibou
# Processing Record 9 of Set 12 | houma
# Processing Record 10 of Set 12 | stephenville
# Processing Record 11 of Set 12 | lasem
# Processing Record 12 of Set 12 | mnogovershinnyy
# Processing Record 13 of Set 12 | choix
# Processing Record 14 of Set 12 | mizdah
# Processing Record 15 of Set 12 | nuuk
# Processing Record 16 of Set 12 | coihaique
# Processing Record 17 of Set 12 | puri
# Processing Record 18 of Set 12 | tianmen
# Processing Record 19 of Set 12 | nizhneudinsk
# Processing Record 20 of Set 12 | zhanaozen
# Processing Record 21 of Set 12 | letterkenny
# Processing Record 22 of Set 12 | luxor
# Processing Record 23 of Set 12 | lishu
# Processing Record 24 of Set 12 | bandundu
# Processing Record 25 of Set 12 | vila do maio
# Processing Record 26 of Set 12 | ende
# Processing Record 27 of Set 12 | toktogul
# Processing Record 28 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 12 | tambura
# Processing Record 30 of Set 12 | stans
# Processing Record 31 of Set 12 | beisfjord
# Processing Record 32 of Set 12 | royan
# Processing Record 33 of Set 12 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 34 of Set 12 | eenhana
# Processing Record 35 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 12 | uinskoye
# Processing Record 37 of Set 12 | bar-le-duc
# Processing Record 38 of Set 12 | le port
# Processing Record 39 of Set 12 | tocopilla
# Processing Record 40 of Set 12 | havoysund
# Processing Record 41 of Set 12 | yumen
# Processing Record 42 of Set 12 | dukat
# Processing Record 43 of Set 12 | usinsk
# Processing Record 44 of Set 12 | batagay-alyta
# Processing Record 45 of Set 12 | sao felix do xingu
# Processing Record 46 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 12 | pyay
# Processing Record 48 of Set 12 | russell
# Processing Record 49 of Set 12 | severo-yeniseyskiy
# Processing Record 50 of Set 12 | feijo
# Processing Record 1 of Set 13 | hobyo
# Processing Record 2 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 13 | gat
# Processing Record 4 of Set 13 | floro
# Processing Record 5 of Set 13 | dunedin
# Processing Record 6 of Set 13 | tual
# Processing Record 7 of Set 13 | san andres
# Processing Record 8 of Set 13 | pishin
# Processing Record 9 of Set 13 | pangai
# Processing Record 10 of Set 13 | gunjur
# Processing Record 11 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 13 | sarankhola
# Processing Record 13 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 13 | zaltan
# Processing Record 15 of Set 13 | kazachinskoye
# Processing Record 16 of Set 13 | iwanai
# Processing Record 17 of Set 13 | xudat
# Processing Record 18 of Set 13 | brae
# Processing Record 19 of Set 13 | caucaia
# Processing Record 20 of Set 13 | mae sai
# Processing Record 21 of Set 13 | ippy
# Processing Record 22 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 13 | kodinsk
# Processing Record 24 of Set 13 | rodental
# Processing Record 25 of Set 13 | jardim
# Processing Record 26 of Set 13 | junction city
# Processing Record 27 of Set 13 | ulaangom
# Processing Record 28 of Set 13 | huilong
# Processing Record 29 of Set 13 | shache
# Processing Record 30 of Set 13 | uarini
# Processing Record 31 of Set 13 | kununurra
# Processing Record 32 of Set 13 | te anau
# Processing Record 33 of Set 13 | kerema
# Processing Record 34 of Set 13 | skibbereen
# Processing Record 35 of Set 13 | beringovskiy
# Processing Record 36 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 13 | paralimni
# Processing Record 38 of Set 13 | arcachon
# Processing Record 39 of Set 13 | sinnamary
# Processing Record 40 of Set 13 | walvis bay
# Processing Record 41 of Set 13 | mackay
# Processing Record 42 of Set 13 | gloucester
# Processing Record 43 of Set 13 | mahebourg
# Processing Record 44 of Set 13 | durham
# Processing Record 45 of Set 13 | itoman
# Processing Record 46 of Set 13 | irbit
# Processing Record 47 of Set 13 | beloha
# Processing Record 48 of Set 13 | praia da vitoria
# Processing Record 49 of Set 13 | rokycany
# Processing Record 50 of Set 13 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 1 of Set 14 | le vauclin
# Processing Record 2 of Set 14 | waddan
# Processing Record 3 of Set 14 | rawson
# Processing Record 4 of Set 14 | urucurituba
# Processing Record 5 of Set 14 | singleton
# Processing Record 6 of Set 14 | christiana
# Processing Record 7 of Set 14 | gimli
# Processing Record 8 of Set 14 | ibipeba
# Processing Record 9 of Set 14 | alice springs
# Processing Record 10 of Set 14 | bengkulu
# Processing Record 11 of Set 14 | bartlesville
# Processing Record 12 of Set 14 | kroya
# Processing Record 13 of Set 14 | catuday
# Processing Record 14 of Set 14 | tommot
# Processing Record 15 of Set 14 | bonthe
# Processing Record 16 of Set 14 | vuktyl
# Processing Record 17 of Set 14 | cassia
# Processing Record 18 of Set 14 | sattenapalle
# Processing Record 19 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 14 | grindavik
# Processing Record 21 of Set 14 | caborca
# Processing Record 22 of Set 14 | zaysan
# Processing Record 23 of Set 14 | dongsheng
# Processing Record 24 of Set 14 | ilo
# Processing Record 25 of Set 14 | rio tuba
# Processing Record 26 of Set 14 | puerto del rosario
# Processing Record 27 of Set 14 | tessalit
# Processing Record 28 of Set 14 | pallasovka
# Processing Record 29 of Set 14 | point pedro
# Processing Record 30 of Set 14 | viedma
# Processing Record 31 of Set 14 | la grande
# Processing Record 32 of Set 14 | kendari
# Processing Record 33 of Set 14 | mongomo
# Processing Record 34 of Set 14 | kousseri
# Processing Record 35 of Set 14 | koratla
# Processing Record 36 of Set 14 | mazamari
# Processing Record 37 of Set 14 | atar
# Processing Record 38 of Set 14 | colares
# Processing Record 39 of Set 14 | stokmarknes
# Processing Record 40 of Set 14 | rapid city
# Processing Record 41 of Set 14 | magadan
# Processing Record 42 of Set 14 | araceli
# Processing Record 43 of Set 14 | ilebo
# Processing Record 44 of Set 14 | coracao de jesus
# Processing Record 45 of Set 14 | aden
# Processing Record 46 of Set 14 | heihe
# Processing Record 47 of Set 14 | kropotkin
# Processing Record 48 of Set 14 | ballybofey
# Processing Record 49 of Set 14 | kangaatsiaq
# Processing Record 50 of Set 14 | morgan city
# Processing Record 1 of Set 15 | alanya
# Processing Record 2 of Set 15 | katobu
# Processing Record 3 of Set 15 | bambanglipuro
# Processing Record 4 of Set 15 | vanersborg
# Processing Record 5 of Set 15 | poum
# Processing Record 6 of Set 15 | kinablangan
# Processing Record 7 of Set 15 | zabaykalsk
# Processing Record 8 of Set 15 | vostok
# Processing Record 9 of Set 15 | egvekinot
# Processing Record 10 of Set 15 | biak
# Processing Record 11 of Set 15 | ketchikan
# Processing Record 12 of Set 15 | lahij
# Processing Record 13 of Set 15 | longido
# Processing Record 14 of Set 15 | nalut
# Processing Record 15 of Set 15 | diu
# Processing Record 16 of Set 15 | strezhevoy
# Processing Record 17 of Set 15 | yebaishou
# Processing Record 18 of Set 15 | bolivar
# Processing Record 19 of Set 15 | dinguiraye
# Processing Record 20 of Set 15 | ravar
# Processing Record 21 of Set 15 | taree
# Processing Record 22 of Set 15 | batagay
# Processing Record 23 of Set 15 | salekhard
# Processing Record 24 of Set 15 | qujing
# Processing Record 25 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 15 | boksitogorsk
# Processing Record 27 of Set 15 | talaya
# Processing Record 28 of Set 15 | cockburn town
# Processing Record 29 of Set 15 | farmington
# Processing Record 30 of Set 15 | gushikawa
# Processing Record 31 of Set 15 | zyryanka
# Processing Record 32 of Set 15 | nikki
# Processing Record 33 of Set 15 | tabukiniberu
# City not found. Skipping...
# Processing Record 34 of Set 15 | wakkanai
# Processing Record 35 of Set 15 | muisne
# Processing Record 36 of Set 15 | chadan
# Processing Record 37 of Set 15 | denpasar
# Processing Record 38 of Set 15 | tkvarcheli
# City not found. Skipping...
# Processing Record 39 of Set 15 | saint combs
# City not found. Skipping...
# Processing Record 40 of Set 15 | maiduguri
# Processing Record 41 of Set 15 | koryukivka
# Processing Record 42 of Set 15 | arona
# Processing Record 43 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 15 | tilichiki
# Processing Record 45 of Set 15 | payo
# Processing Record 46 of Set 15 | paracuru
# Processing Record 47 of Set 15 | thaton
# Processing Record 48 of Set 15 | nha trang
# Processing Record 49 of Set 15 | port macquarie
# Processing Record 50 of Set 15 | zhangye
# Processing Record 1 of Set 16 | beipiao
# Processing Record 2 of Set 16 | kirillov
# Processing Record 3 of Set 16 | arman
# Processing Record 4 of Set 16 | muromtsevo
# Processing Record 5 of Set 16 | ambilobe
# Processing Record 6 of Set 16 | bilma
# Processing Record 7 of Set 16 | fukuma
# Processing Record 8 of Set 16 | baoying
# Processing Record 9 of Set 16 | kamaishi
# Processing Record 10 of Set 16 | bayji
# Processing Record 11 of Set 16 | boca do acre
# Processing Record 12 of Set 16 | xam nua
# Processing Record 13 of Set 16 | solnechnyy
# Processing Record 14 of Set 16 | muroto
# Processing Record 15 of Set 16 | laguna
# Processing Record 16 of Set 16 | togur
# Processing Record 17 of Set 16 | high level
# Processing Record 18 of Set 16 | roebourne
# Processing Record 19 of Set 16 | nacimiento
# Processing Record 20 of Set 16 | warri
# Processing Record 21 of Set 16 | san carlos de bariloche
# Processing Record 22 of Set 16 | marquette
# Processing Record 23 of Set 16 | petatlan
# Processing Record 24 of Set 16 | tarko-sale
# Processing Record 25 of Set 16 | svetlaya
# Processing Record 26 of Set 16 | tobermory
# Processing Record 27 of Set 16 | kalyazin
# Processing Record 28 of Set 16 | nenjiang
# Processing Record 29 of Set 16 | ayer itam
# City not found. Skipping...
# Processing Record 30 of Set 16 | khani
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tallying number of cities in the city_data array of dictionaries.
len(city_data)
# Out:
# 728

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     76.96        88          53
# 1     Langxiang  46.9500  128.8833     56.62        92          66
# 2       Ajaccio  42.0000    8.9167     69.85        68          40
# 3  Jacareacanga  -6.2222  -57.7528     81.34        71         100
# 4        Albany  42.6001  -73.9662     75.79        49          23
# 5        Bethel  41.3712  -73.4140     83.01        46           0
# 6  San Patricio  28.0170  -97.5169     95.09        44           4
# 7     Busselton -33.6500  115.3333     59.34        59          67
# 8         Kapaa  22.0752 -159.3190     83.48        73           0
# 9        Ixtapa  20.7000 -105.2000     79.83        78         100
#
#    Wind Speed Country                 Date
# 0        5.99      EC  2022-06-08 21:22:48
# 1        2.44      CN  2022-06-08 21:22:48
# 2        4.61      FR  2022-06-08 21:22:49
# 3        2.21      BR  2022-06-08 21:22:49
# 4        1.01      US  2022-06-08 21:20:30
# 5        5.75      US  2022-06-08 21:22:50
# 6       18.84      US  2022-06-08 21:22:50
# 7       15.32      AU  2022-06-08 21:22:50
# 8        8.05      US  2022-06-08 21:22:50
# 9       10.36      MX  2022-06-08 21:22:51

# %%
# Reordering the columns.
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Puerto Ayora      EC  2022-06-08 21:22:48  -0.7393  -90.3518     76.96
# 1     Langxiang      CN  2022-06-08 21:22:48  46.9500  128.8833     56.62
# 2       Ajaccio      FR  2022-06-08 21:22:49  42.0000    8.9167     69.85
# 3  Jacareacanga      BR  2022-06-08 21:22:49  -6.2222  -57.7528     81.34
# 4        Albany      US  2022-06-08 21:20:30  42.6001  -73.9662     75.79
# 5        Bethel      US  2022-06-08 21:22:50  41.3712  -73.4140     83.01
# 6  San Patricio      US  2022-06-08 21:22:50  28.0170  -97.5169     95.09
# 7     Busselton      AU  2022-06-08 21:22:50 -33.6500  115.3333     59.34
# 8         Kapaa      US  2022-06-08 21:22:50  22.0752 -159.3190     83.48
# 9        Ixtapa      MX  2022-06-08 21:22:51  20.7000 -105.2000     79.83
#
#    Humidity  Cloudiness  Wind Speed
# 0        88          53        5.99
# 1        92          66        2.44
# 2        68          40        4.61
# 3        71         100        2.21
# 4        49          23        1.01
# 5        46           0        5.75
# 6        44           4       18.84
# 7        59          67       15.32
# 8        73           0        8.05
# 9        78         100       10.36

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
